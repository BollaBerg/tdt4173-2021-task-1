# %%
# %load_ext autoreload

# %%
# %autoreload
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import k_means as km

sns.set_style('darkgrid')

# %%
DATA_PATH = Path("data_2.csv").resolve()
data_2 = pd.read_csv(DATA_PATH)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.scatterplot(x='x0', y='x1', data=data_2, ax=ax[0])
sns.scatterplot(x='x0', y='x1', data=data_2, ax=ax[1])
ax[1].set_xlim(-2, 11)
ax[1].set_ylim(-2, 11)
# Out:
# (-2.0, 11.0)
