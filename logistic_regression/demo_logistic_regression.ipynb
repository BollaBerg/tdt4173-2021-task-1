# %%
# %load_ext autoreload

# %%
# %autoreload 

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import logistic_regression as lr   # <-- Your implementation

sns.set_style('darkgrid') # Seaborn plotting style

# %%
data_2 = pd.read_csv('data_2.csv')

# %%
### DATA DISTRIBUTION ###
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.scatterplot(x='x0', y='x1', hue='y', data=data_2, ax=ax[0])

processed_data = lr.preprocessing_cartesian_to_polar_coordinates(data_2)
processed_data['y'] = data_2['y']
sns.scatterplot(x='Distances', y='Angles', hue='y', data=processed_data, ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Distances', ylabel='Angles'>
